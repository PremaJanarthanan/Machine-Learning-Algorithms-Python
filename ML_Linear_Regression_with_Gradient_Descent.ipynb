# %%
#import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (9.0,6.0) #RuntimeConfiguration figure size

# %%
# Preprocessing the input data
data = pd.read_csv("C:/Prema/Data Science/ML algorithms/linear regression/data.csv")
X = data.iloc[:,0]
Y = data.iloc[:,1]
plt.scatter(x,y) #we can predict with linear line
plt.show()

# %%
#Bulding the model
m = 0  #slope
c = 0  # Y intercept
L = 0.0001  #Learning rate (how much jump to take, slow or fast)

epochs = 1000  # The number of iterations to perform gradient descent
n = float(len(X)) # Number of elements in X

# Performing Gradient Descent 

for i in range(epochs): 
    Y_pred = m*X + c  # The current predicted value of Y
    D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(Y - Y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c
    
print (m, c)
# Out:
# 1.4796491688889395 0.10148121494753726

# %%
# Making predictions
Y_pred = m*X + c

plt.scatter(X, Y) 
plt.scatter(X, Y_pred)

# %%
plt.scatter(X, Y) 
plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red')  # regression line, giving set of x and y values
plt.show()
